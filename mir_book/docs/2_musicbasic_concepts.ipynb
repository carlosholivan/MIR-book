# %% [markdown]
# # Music and Sound Basic Concepts
#
#
#
# ## 1. What is music?
#
#
#
# ## 2. Music Basic Principles
#
# ### 2.1. Melody
#
# ### 2.2. Harmony
#
# #### Key or Tonality
#
# #### Chord
#
# #### Chord or HArmonic Progression
#
# ### 2.3. Rhythm
#
# ### 2.4. Form or Structure
#
# ### 2.5. Texture
#
#
#
# ## 3. Instruments and Tracks
#
# ### 3.1. Instruments
#
# ### 3.2. Ensemble
#
# ### 3.3. Orchestra
#
#
#
# ## 4. Sound
#
# ### 4.1. Expression
#
# #### Dynamics
#
# #### Tempo
#
# #### Articulations
#
# ### 4.2. Synthesis
#
#
# ## 5. Music Representations
#
# ### 5.1. Music Score or Sheet
#
# ### 5.2. Pianoroll
#
#
# ## 6. Interfaces
#
# ### 6.1. Musical Instrument Digital Interface (MIDI)
#
# #### Tracks
#
# Program number
#
# Channel
#
# #### Note Events
#
# Note on
#
# Note off
#
# Velocity
#
# Ticks
#
# PPQ (pulses per quarter note)
#
# ### 6.2. Digital Audio Workstation (DAW)
